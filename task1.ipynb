# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

# %%
# %matplotlib notebook

# %%
data = pd.read_csv('task1.csv')

# %%
data.head()
# Out:
#            x           y
# 0  83.999961  112.270745
# 1  98.500198  172.083101
# 2  72.000477   88.263026
# 3  73.499214   89.457834
# 4  18.000170   39.641650

# %%
print(data.shape)
# Out:
# (96, 2)

# %%
x = np.array(data['x'])
y = np.array(data['y'])

# %%
plt.scatter(x, y, s=10)
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x_without_2 = np.delete(x, np.where((x<50) & (y>80)))
y_without_2 = np.delete(y, np.where((x<50) & (y>80)))

x_without_3 = np.delete(x_without_2, np.where(y_without_2<25))
y_without_3 = np.delete(y_without_2, np.where(y_without_2<25))

# %%
plt.scatter(x, y, s=10)
plt.scatter(x_without_2, y_without_2, s=10)
plt.scatter(x_without_3, y_without_3, s=10)
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
z_1 = np.poly1d(np.polyfit(x,y,2))
z_2 = np.poly1d(np.polyfit(x_without_2,y_without_2,2))
z_3 = np.poly1d(np.polyfit(x_without_3,y_without_3,2))

# %%
r = range(9,101)

plt.plot(r, [z_1(i) for i in r], linewidth=2, label='full sample')
plt.plot(r, [z_2(i) for i in r], linewidth=2, label='without 2 outliers')
plt.plot(r, [z_3(i) for i in r], linewidth=2, label='without 3 outliers')
plt.scatter(x, y, s=10, c='k')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print('Full sample:', np.sqrt(sum((y - [z(i) for i in x])**2)/len(y)))
print('Without 2 outliers:', np.sqrt(sum((y_without_2 - [z(i) for i in x_without_2])**2)/len(y_without_2)))
print('Without 3 outliers:', np.sqrt(sum((y_without_3 - [z(i) for i in x_without_3])**2)/len(y_without_3)))
# Out:
# Full sample: 16.78018802676605
# Without 2 outliers: 4.85584051724419
# Without 3 outliers: 4.553070539851498

# %%
z_2 = np.poly1d(np.polyfit(x_without_2,y_without_2,2))
z_3 = np.poly1d(np.polyfit(x_without_2,y_without_2,3))
z_4 = np.poly1d(np.polyfit(x_without_2,y_without_2,4))
z_5 = np.poly1d(np.polyfit(x_without_2,y_without_2,5))
z_6 = np.poly1d(np.polyfit(x_without_2,y_without_2,6))
z_7 = np.poly1d(np.polyfit(x_without_2,y_without_2,7))
z_8 = np.poly1d(np.polyfit(x_without_2,y_without_2,8))

# %%
r = range(9,101)

plt.plot(r, [z_2(i) for i in r], linewidth=2, label='2 degree')
# plt.plot(r, [z_3(i) for i in r], linewidth=2, label='3 degree')
# plt.plot(r, [z_4(i) for i in r], linewidth=2, label='4 degree')
plt.plot(r, [z_5(i) for i in r], linewidth=2, label='5 degree')
# plt.plot(r, [z_6(i) for i in r], linewidth=2, label='6 degree')
# plt.plot(r, [z_7(i) for i in r], linewidth=2, label='7 degree')
plt.plot(r, [z_8(i) for i in r], linewidth=2, label='8 degree')
plt.scatter(x, y, s=10, c='k')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print('2 degree:', np.sqrt(sum((y_without_2 - [z_2(i) for i in x_without_2])**2)/len(y_without_2)))
# print('3 degree:', np.sqrt(sum((y_without_2 - [z_3(i) for i in x_without_2])**2)/len(y_without_2)))
# print('4 degree:', np.sqrt(sum((y_without_2 - [z_4(i) for i in x_without_2])**2)/len(y_without_2)))
print('5 degree:', np.sqrt(sum((y_without_2 - [z_5(i) for i in x_without_2])**2)/len(y_without_2)))
# print('6 degree:', np.sqrt(sum((y_without_2 - [z_6(i) for i in x_without_2])**2)/len(y_without_2)))
# print('7 degree:', np.sqrt(sum((y_without_2 - [z_7(i) for i in x_without_2])**2)/len(y_without_2)))
print('8 degree:', np.sqrt(sum((y_without_2 - [z_8(i) for i in x_without_2])**2)/len(y_without_2)))
# Out:
# 2 degree: 4.85584051724419
# 5 degree: 3.661035754766476
# 8 degree: 3.301633539907027
